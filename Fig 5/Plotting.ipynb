# %% [markdown]
# # $\color{red}{ Plotting \ the \ derivative}$

# %%
import tools_plotting as tools

from matplotlib import pyplot as plt

# %% [markdown]
# Here we plot figure 5 of the paper

# %%
layers_max=90
ds=[3,5]
n=6
samples=640
noise={"amp_damping":0.004}
noise_position="after_layer"

tools.plot_der(layers_max=layers_max,samples=samples,noise=noise,noise_position=noise_position,n=n,ds=ds)

# %%
# for creating a pdf
fig=tools.plot_der(layers_max=layers_max,samples=samples,noise=noise,noise_position=noise_position,n=n,ds=ds)


plt.savefig("Fig_5.pdf", format="pdf", bbox_inches="tight",dpi=300)
