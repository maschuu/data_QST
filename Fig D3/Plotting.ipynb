# %% [markdown]
# # $\color{red}{ Plotting \ Fig  \ D3 }$

# %%
import tools_plotting as tools

from matplotlib import pyplot as plt

# %% [markdown]
# Here we plot figure D3 of the paper.

# %%
# common parameters
samples=64
n=6
noise_position="after_layer"

#parameters for fig D2a
strength_a=0.004
noise_a={"amp_damping":strength_a}
layers_max_a=90
ds_a=[2,3,4,5]

# parameters for fig D2b
strengths_b=[0.001,0.002,0.004]
noise_type_b="amp_damping"
layers_max_b=250
d_b=3

tools.plot_infids(samples=samples,n=n,noise_position=noise_position,strength_a=strength_a,noise_a=noise_a,layers_max_a=layers_max_a,ds_a=ds_a,d_b=d_b,layers_max_b=layers_max_b,noise_type_b=noise_type_b,strengths_b=strengths_b)

# %%
# for creating a pdf
fig=tools.plot_infids(samples=samples,n=n,noise_position=noise_position,strength_a=strength_a,noise_a=noise_a,layers_max_a=layers_max_a,ds_a=ds_a,d_b=d_b,layers_max_b=layers_max_b,noise_type_b=noise_type_b,strengths_b=strengths_b)

plt.savefig("Fig_D3.pdf", format="pdf", bbox_inches="tight",dpi=300)
