# %% [markdown]
# # $\color{red}{ Plotting \ Fig \ D2 }$

# %%
from matplotlib import pyplot as plt

import tools_plotting as tools

# %% [markdown]
# Here we plot figure D2 of the paper.

# %%
ds=[2,3,4,5]
n=6
noise={"amp_damping":0.06}
samples=96*8
layers_max=30

tools.plot_fidelities_qaoa(n=n,ds=ds,noise=noise,samples=samples,layers_max=layers_max)

# %%
# for creating a pdf
fig=tools.plot_fidelities_qaoa(n=n,ds=ds,noise=noise,samples=samples,layers_max=layers_max)

plt.savefig("Fig_D2.pdf", format="pdf", bbox_inches="tight",dpi=300)
