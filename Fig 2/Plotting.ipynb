# %% [markdown]
# # $\color{red}{ Plotting \ Fig \ 2}$

# %%
import tools_plotting as tools

from matplotlib import pyplot as plt

# %% [markdown]
# Here we plot figure 2 of the paper.

# %%
# n : number of qubits
n=6
strength=0.004
noise={"amp_damping":strength }
layers_max=140
# pmax: maximal probability that the single instance purity lies outside the plotted bounds
pmax=0.01

tools.plot_purity_toy_model(n=n,noise=noise,layers_max=layers_max,pmax=pmax)

# %%
# for creating a pdf
fig=tools.plot_purity_toy_model(n=n,noise=noise,layers_max=layers_max,pmax=pmax)

plt.savefig("Fig_2.pdf", format="pdf", bbox_inches="tight",dpi=300)
