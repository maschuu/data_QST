# %% [markdown]
# # $\color{red}{ Plotting \ Fig  \ 4}$

# %%
import tools_plotting as tools

from matplotlib import pyplot as plt

import numpy as np

# %% [markdown]
# Here we plot figure 4 of the paper.

# %%
# common parameters
noise_type="amp_damping"
strengths=4*np.array([0.001,0.002,0.005,0.01])
noise_position="after_layer"
samples=64*2
n=6


#parameters for fig 4a
layers_max_a=90
#considering a 3-regular graph and a 5-regular graph
ds_a=[3,5]


#parameters for fig 4b
layers_max_b=160
d_b=3

tools.plot_purs_std(noise_type=noise_type,strengths=strengths,noise_position=noise_position,samples=samples,n=n,layers_max_a=layers_max_a,ds_a=ds_a,layers_max_b=layers_max_b,d_b=d_b)

# %%
# for creating a pdf
fig=tools.plot_purs_std(noise_type=noise_type,strengths=strengths,noise_position=noise_position,samples=samples,n=n,layers_max_a=layers_max_a,ds_a=ds_a,layers_max_b=layers_max_b,d_b=d_b)

plt.savefig("Fig_4.pdf", format="pdf", bbox_inches="tight",dpi=300)
